# %%
import pandas as pd
import numpy as np
import tensorflow_hub as hub
from sklearn.model_selection import GroupKFold
from sklearn.metrics import roc_auc_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import tensorflow as tf

# Setting a seed for reproducibility
SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)

# Load Universal Sentence Encoder
embed = hub.load("https://tfhub.dev/google/universal-sentence-encoder-large/5")

# Load data
df = pd.read_csv('Data/Annotations_final.csv')

# Handling potential missing values or preprocessing steps
# df = df.dropna()  # Example: Drop rows with missing values
# df['annotation_text'] = df['annotation_text'].apply(lambda x: preprocess_text(x)) # Example: Preprocess text

# Grouping data for cross-validation
group_dict = dict()
groups = np.array([])

for index, row in df.iterrows():
    s_id = row['created_by']
    if s_id not in group_dict:
        group_dict[s_id] = index
    groups = np.append(groups, group_dict[s_id])

# Set up the splitter
gkf = GroupKFold(n_splits=5)

# Extract features and labels
X = df['annotation_text']
y = df['comment_answer']

# Storage for performance metrics
roc_auc_scores = np.array([])

# Model Training and Evaluation
for train_index, test_index in gkf.split(X, y, groups=groups):
    try:
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]

        # Convert texts to embeddings
        training_embeddings = embed(X_train.to_list())
        testing_embeddings = embed(X_test.to_list())

        # Define the model
        model = Sequential([
            Dense(12, activation='relu', input_shape=(512,)),
            Dense(8, activation='relu'),
            Dense(1, activation='sigmoid')
        ])

        model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

        # Model training
        model.fit(training_embeddings, y_train, epochs=30, validation_split=0.1, shuffle=True, batch_size=10)

        # Model evaluation
        predictions = model.predict(testing_embeddings)
        roc_auc_scores = np.append(roc_auc_scores, roc_auc_score(y_test, predictions))
    except Exception as e:
        print(f"An error occurred: {e}")

# Output the results
print(f"Average ROC AUC Score: {np.round(roc_auc_scores.mean(), 3)}")
print(f"ROC AUC Score Standard Deviation: {np.round(roc_auc_scores.std(), 3)}")
print(f"Maximum ROC AUC Score: {np.round(roc_auc_scores.max(), 3)}")
# Out:
# WARNING:tensorflow:From C:\Users\Cesar\Desktop\TF Projects\tfvenv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\Cesar\Desktop\TF Projects\tfvenv\lib\site-packages\tensorflow_estimator\python\estimator\util.py:74: The name tf.train.SessionRunHook is deprecated. Please use tf.estimator.SessionRunHook instead.
#
# WARNING:tensorflow:From C:\Users\Cesar\Desktop\TF Projects\tfvenv\lib\site-packages\tensorflow_hub\native_module.py:92: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From C:\Users\Cesar\Desktop\TF Projects\tfvenv\lib\site-packages\tensorflow_hub\saved_model_module.py:40: The name tf.saved_model.constants.LEGACY_INIT_OP_KEY is deprecated. Please use tf.compat.v1.saved_model.constants.LEGACY_INIT_OP_KEY instead.
#
# WARNING:tensorflow:From C:\Users\Cesar\Desktop\TF Projects\tfvenv\lib\site-packages\tensorflow_hub\resolver.py:120: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
# WARNING:tensorflow:From C:\Users\Cesar\Desktop\TF Projects\tfvenv\lib\site-packages\tensorflow_hub\resolver.py:120: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
# WARNING:tensorflow:From C:\Users\Cesar\Desktop\TF Projects\tfvenv\lib\site-packages\tensorflow_hub\module_v2.py:120: The name tf.saved_model.load_v2 is deprecated. Please use tf.compat.v2.saved_model.load instead.
# WARNING:tensorflow:From C:\Users\Cesar\Desktop\TF Projects\tfvenv\lib\site-packages\tensorflow_hub\module_v2.py:120: The name tf.saved_model.load_v2 is deprecated. Please use tf.compat.v2.saved_model.load instead.
# WARNING:tensorflow:From C:\Users\Cesar\Desktop\TF Projects\tfvenv\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
# WARNING:tensorflow:From C:\Users\Cesar\Desktop\TF Projects\tfvenv\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
# Epoch 1/30
# WARNING:tensorflow:From C:\Users\Cesar\Desktop\TF Projects\tfvenv\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
# WARNING:tensorflow:From C:\Users\Cesar\Desktop\TF Projects\tfvenv\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
# 17/17 [==============================] - 1s 10ms/step - loss: 0.6785 - accuracy: 0.7744 - val_loss: 0.6542 - val_accuracy: 0.8947
# Epoch 2/30
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6152 - accuracy: 0.8841 - val_loss: 0.5768 - val_accuracy: 0.8947
# Epoch 3/30
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5270 - accuracy: 0.8841 - val_loss: 0.4915 - val_accuracy: 0.8947
# Epoch 4/30
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4472 - accuracy: 0.8841 - val_loss: 0.4195 - val_accuracy: 0.8947
# Epoch 5/30
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3837 - accuracy: 0.8841 - val_loss: 0.3665 - val_accuracy: 0.8947
# Epoch 6/30
# 17/17 [==============================] - 0s 2ms/step - loss: 0.3416 - accuracy: 0.8841 - val_loss: 0.3279 - val_accuracy: 0.8947
# Epoch 7/30
# 17/17 [==============================] - 0s 2ms/step - loss: 0.3109 - accuracy: 0.8841 - val_loss: 0.2987 - val_accuracy: 0.8947
# Epoch 8/30
# 17/17 [==============================] - 0s 2ms/step - loss: 0.2844 - accuracy: 0.8841 - val_loss: 0.2701 - val_accuracy: 0.8947
# Epoch 9/30
# 17/17 [==============================] - 0s 2ms/step - loss: 0.2581 - accuracy: 0.8902 - val_loss: 0.2492 - val_accuracy: 0.8947
# Epoch 10/30
# 17/17 [==============================] - 0s 2ms/step - loss: 0.2335 - accuracy: 0.9024 - val_loss: 0.2230 - val_accuracy: 0.8947
# Epoch 11/30
# 17/17 [==============================] - 0s 2ms/step - loss: 0.2103 - accuracy: 0.9146 - val_loss: 0.2043 - val_accuracy: 0.9474
# Epoch 12/30
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1914 - accuracy: 0.9146 - val_loss: 0.1934 - val_accuracy: 0.9474
# Epoch 13/30
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1707 - accuracy: 0.9512 - val_loss: 0.1737 - val_accuracy: 0.9474
# Epoch 14/30
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1518 - accuracy: 0.9573 - val_loss: 0.1570 - val_accuracy: 0.9474
# Epoch 15/30
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0945 - accuracy: 0.9695 - val_loss: 0.2233 - val_accuracy: 0.8947
# Epoch 25/30
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0916 - accuracy: 0.9634 - val_loss: 0.2263 - val_accuracy: 0.8947
# Epoch 26/30
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0840 - accuracy: 0.9756 - val_loss: 0.2149 - val_accuracy: 0.9474
# Epoch 27/30
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0776 - accuracy: 0.9817 - val_loss: 0.2244 - val_accuracy: 0.9474
# Epoch 28/30
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0735 - accuracy: 0.9817 - val_loss: 0.2192 - val_accuracy: 0.9474
# Epoch 29/30
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0695 - accuracy: 0.9878 - val_loss: 0.2273 - val_accuracy: 0.9474
# Epoch 30/30
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0645 - accuracy: 0.9878 - val_loss: 0.2219 - val_accuracy: 0.9474
# 2/2 [==============================] - 0s 2ms/step
# Epoch 1/30
# 17/17 [==============================] - 1s 8ms/step - loss: 0.6632 - accuracy: 0.8354 - val_loss: 0.6371 - val_accuracy: 0.8421
# Epoch 2/30
# 17/17 [==============================] - 0s 3ms/step - loss: 0.5752 - accuracy: 0.8963 - val_loss: 0.5530 - val_accuracy: 0.8421
# Epoch 3/30
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4711 - accuracy: 0.8963 - val_loss: 0.4782 - val_accuracy: 0.8421
# Epoch 4/30
# 17/17 [==============================] - 0s 2ms/step - loss: 0.3850 - accuracy: 0.8963 - val_loss: 0.4321 - val_accuracy: 0.8421
# Epoch 5/30
# 17/17 [==============================] - 0s 2ms/step - loss: 0.3355 - accuracy: 0.8963 - val_loss: 0.4094 - val_accuracy: 0.8421
# Epoch 6/30
# 17/17 [==============================] - 0s 2ms/step - loss: 0.3061 - accuracy: 0.8963 - val_loss: 0.3948 - val_accuracy: 0.8421
# Epoch 7/30
# 17/17 [==============================] - 0s 2ms/step - loss: 0.2845 - accuracy: 0.8963 - val_loss: 0.3807 - val_accuracy: 0.8421
# Epoch 8/30
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2653 - accuracy: 0.8963 - val_loss: 0.3662 - val_accuracy: 0.8421
# Epoch 9/30
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2489 - accuracy: 0.8963 - val_loss: 0.3515 - val_accuracy: 0.8421
# Epoch 10/30
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2334 - accuracy: 0.8963 - val_loss: 0.3404 - val_accuracy: 0.8421
# Epoch 11/30
# 17/17 [==============================] - 0s 2ms/step - loss: 0.2203 - accuracy: 0.8963 - val_loss: 0.3284 - val_accuracy: 0.8421
# Epoch 12/30
# 17/17 [==============================] - 0s 2ms/step - loss: 0.2080 - accuracy: 0.8963 - val_loss: 0.3210 - val_accuracy: 0.8421
# Epoch 13/30
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1966 - accuracy: 0.8963 - val_loss: 0.3053 - val_accuracy: 0.8421
# Epoch 14/30
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1868 - accuracy: 0.8963 - val_loss: 0.2979 - val_accuracy: 0.8421
# Epoch 15/30
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1785 - accuracy: 0.8963 - val_loss: 0.2961 - val_accuracy: 0.8421
# Epoch 16/30
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1715 - accuracy: 0.8963 - val_loss: 0.2840 - val_accuracy: 0.8421
# Epoch 17/30
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1631 - accuracy: 0.8963 - val_loss: 0.2814 - val_accuracy: 0.8421
# Epoch 18/30
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1568 - accuracy: 0.8963 - val_loss: 0.2806 - val_accuracy: 0.8421
# Epoch 19/30
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1520 - accuracy: 0.8963 - val_loss: 0.2732 - val_accuracy: 0.8421
# Epoch 20/30
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1456 - accuracy: 0.8963 - val_loss: 0.2762 - val_accuracy: 0.8421
# Epoch 21/30
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1407 - accuracy: 0.8963 - val_loss: 0.2735 - val_accuracy: 0.8421
# Epoch 22/30
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1366 - accuracy: 0.8963 - val_loss: 0.2704 - val_accuracy: 0.8421
# Epoch 23/30
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1319 - accuracy: 0.8963 - val_loss: 0.2666 - val_accuracy: 0.8421
# Epoch 24/30
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1285 - accuracy: 0.8963 - val_loss: 0.2690 - val_accuracy: 0.8421
# Epoch 25/30
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1234 - accuracy: 0.8963 - val_loss: 0.2629 - val_accuracy: 0.8421
# Epoch 26/30
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1211 - accuracy: 0.8963 - val_loss: 0.2540 - val_accuracy: 0.8421
# Epoch 27/30
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1156 - accuracy: 0.9329 - val_loss: 0.2561 - val_accuracy: 0.8947
# Epoch 28/30
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1123 - accuracy: 0.9512 - val_loss: 0.2554 - val_accuracy: 0.8947
# Epoch 29/30
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1089 - accuracy: 0.9634 - val_loss: 0.2507 - val_accuracy: 0.8947
# Epoch 30/30
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1052 - accuracy: 0.9634 - val_loss: 0.2556 - val_accuracy: 0.8947
# 2/2 [==============================] - 0s 3ms/step
# Epoch 1/30
# 17/17 [==============================] - 1s 8ms/step - loss: 0.6218 - accuracy: 0.9030 - val_loss: 0.5994 - val_accuracy: 0.7895
# Epoch 2/30
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4867 - accuracy: 0.9030 - val_loss: 0.5195 - val_accuracy: 0.7895
# Epoch 3/30
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3740 - accuracy: 0.9030 - val_loss: 0.4816 - val_accuracy: 0.7895
# Epoch 4/30
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3172 - accuracy: 0.9030 - val_loss: 0.4706 - val_accuracy: 0.7895
# Epoch 5/30
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2864 - accuracy: 0.9030 - val_loss: 0.4534 - val_accuracy: 0.7895
# Epoch 6/30
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2638 - accuracy: 0.9030 - val_loss: 0.4294 - val_accuracy: 0.7895
# Epoch 7/30
# 17/17 [==============================] - 0s 2ms/step - loss: 0.2411 - accuracy: 0.9030 - val_loss: 0.3930 - val_accuracy: 0.7895
# Epoch 8/30
# 17/17 [==============================] - 0s 2ms/step - loss: 0.2196 - accuracy: 0.9030 - val_loss: 0.3686 - val_accuracy: 0.7895
# Epoch 9/30
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1999 - accuracy: 0.9030 - val_loss: 0.3486 - val_accuracy: 0.7895
# Epoch 10/30
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1829 - accuracy: 0.9030 - val_loss: 0.3247 - val_accuracy: 0.7895
# Epoch 11/30
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1664 - accuracy: 0.9091 - val_loss: 0.3024 - val_accuracy: 0.8421
# Epoch 12/30
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1525 - accuracy: 0.9273 - val_loss: 0.2988 - val_accuracy: 0.8421
# Epoch 13/30
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1402 - accuracy: 0.9515 - val_loss: 0.2708 - val_accuracy: 0.8421
# Epoch 14/30
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1289 - accuracy: 0.9636 - val_loss: 0.2730 - val_accuracy: 0.8421
# Epoch 15/30
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1201 - accuracy: 0.9636 - val_loss: 0.2450 - val_accuracy: 0.8947
# Epoch 16/30
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1102 - accuracy: 0.9636 - val_loss: 0.2458 - val_accuracy: 0.8947
# Epoch 17/30
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1021 - accuracy: 0.9758 - val_loss: 0.2426 - val_accuracy: 0.8947
# Epoch 18/30
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0950 - accuracy: 0.9758 - val_loss: 0.2347 - val_accuracy: 0.8947
# Epoch 19/30
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0891 - accuracy: 0.9697 - val_loss: 0.2322 - val_accuracy: 0.8947
# Epoch 20/30
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0832 - accuracy: 0.9636 - val_loss: 0.2211 - val_accuracy: 0.8947
# Epoch 21/30
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0813 - accuracy: 0.9697 - val_loss: 0.2146 - val_accuracy: 0.9474
# Epoch 22/30
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0747 - accuracy: 0.9818 - val_loss: 0.2224 - val_accuracy: 0.8947
# Epoch 23/30
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0690 - accuracy: 0.9758 - val_loss: 0.2152 - val_accuracy: 0.9474
# Epoch 24/30
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0649 - accuracy: 0.9818 - val_loss: 0.2047 - val_accuracy: 0.9474
# Epoch 25/30
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0614 - accuracy: 0.9818 - val_loss: 0.2112 - val_accuracy: 0.9474
# Epoch 26/30
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0586 - accuracy: 0.9879 - val_loss: 0.2121 - val_accuracy: 0.9474
# Epoch 27/30
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0544 - accuracy: 0.9879 - val_loss: 0.2046 - val_accuracy: 0.9474
# Epoch 28/30
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0520 - accuracy: 0.9939 - val_loss: 0.2013 - val_accuracy: 0.9474
# Epoch 29/30
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0489 - accuracy: 0.9939 - val_loss: 0.1995 - val_accuracy: 0.9474
# Epoch 30/30
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0467 - accuracy: 0.9939 - val_loss: 0.2081 - val_accuracy: 0.9474
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000241D0F04280> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000241D0F04280> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 1ms/step
# Average ROC AUC Score: 0.959
# ROC AUC Score Standard Deviation: 0.026
# Maximum ROC AUC Score: 0.988
